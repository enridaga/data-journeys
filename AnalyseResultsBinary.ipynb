# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
BC = pd.read_csv("ClassificationExperiments.csv",names=["Dataset", "Notebooks", "EmbMethod", "InputSize", "TestRegime", "Method", "Accuracy", "Matthews", "F1:A", "F1:B" ])
# Preview the first 5 lines of the loaded data 
# data.head()
BC.size
# Out:
# 21540

# %%
BC['Method'].unique()
# Out:
# array(['Decision Tree', 'GaussianNB', 'LogisticRegression', 'LinearSVC',
#        'MLPClassifier', 'RandomForestClassifier'], dtype=object)

# %%
#

# %%
# Group data by Dataset/InputSize/TestRegime/Method and compute AVG & STD on each Measures
# avg = data[(data['Dataset']=='BC_VisualisationPreparation.csv') & (data['InputSize']==10) & (data['TestRegime']==1) & (data['Method']=='Decision Tree')].mean()
# std = data[(data['Dataset']=='BC_VisualisationPreparation.csv') & (data['InputSize']==10) & (data['TestRegime']==1) & (data['Method']=='Decision Tree')].std()
# avg, std
# # https://stackoverflow.com/questions/36106490/how-to-get-unique-values-from-multiple-columns-in-a-pandas-groupby

# %%
def Table(dataframe, dataset, test_regime):
    # VP, TestRegime 1
    df = dataframe[dataframe['Dataset'] == dataset].drop(columns=['Notebooks','Dataset'])
    TR = df.loc[df['TestRegime']==test_regime].drop(columns=['TestRegime'])
    return TR.groupby(["EmbMethod",'InputSize','Method']).agg(['mean','std'])

# %% [markdown]
# ## Test regime 1
# Train and test entities randomly split

# %%
# Train and test entities randomly split
Table(BC, 'BC_OutputTemporary.csv', 1 )
# Out:
#                                             Accuracy            Matthews  \
#                                                 mean       std      mean
# EmbMethod InputSize Method
# bertcode  10        Decision Tree           0.577051  0.252038  0.179078
#                     GaussianNB              0.622766  0.276111  0.387714
#                     LinearSVC               0.472725  0.438203  0.009850
#                     LogisticRegression      0.386693  0.158639  0.000000
#                     MLPClassifier           0.599950  0.276495  0.169645
#                     RandomForestClassifier  0.663972  0.197592  0.225267
#           100       Decision Tree           0.801900  0.218581  0.526294
#                     GaussianNB              0.593144  0.283216  0.385194
#                     LinearSVC               0.619094  0.435600  0.248237
#                     LogisticRegression      0.332707  0.034260  0.000000
# ...

# %%
Table(BC, 'BC_VisualisationPreparation.csv', 1 )
# Out:
#                                             Accuracy            Matthews  \
#                                                 mean       std      mean
# EmbMethod InputSize Method
# bertcode  10        Decision Tree           0.675211  0.216436  0.405456
#                     GaussianNB              0.599964  0.247060  0.334643
#                     LinearSVC               0.684054  0.290823  0.382693
#                     LogisticRegression      0.498224  0.194070  0.083797
#                     MLPClassifier           0.659562  0.168940  0.265328
#                     RandomForestClassifier  0.767949  0.193718  0.545409
#           100       Decision Tree           0.683299  0.168713  0.374693
#                     GaussianNB              0.683423  0.109741  0.448375
#                     LinearSVC               0.587500  0.343584  0.166774
#                     LogisticRegression      0.469520  0.035593  0.000000
# ...

# %% [markdown]
# ## Test Regime 2
#
# Train and test do not share notebooks

# %%
# Train and test entities randomly split
# Train and test do not share notebooks
# Train and test do not have nodes sharing the same direct arc
Table(BC, 'BC_OutputTemporary.csv', 2 )
# Out:
#                                             Accuracy            Matthews  \
#                                                 mean       std      mean
# EmbMethod InputSize Method
# bertcode  10        Decision Tree           0.657277  0.278830  0.207870
#                     GaussianNB              0.741040  0.261107  0.361188
#                     LinearSVC               0.645625  0.355712  0.137641
#                     LogisticRegression      0.588706  0.277454  0.126008
#                     MLPClassifier           0.583337  0.339475  0.252823
#                     RandomForestClassifier  0.735126  0.260813  0.298031
#           100       Decision Tree           0.668346  0.190340  0.257420
#                     GaussianNB              0.586171  0.237804  0.347711
#                     LinearSVC               0.395752  0.409383 -0.208316
#                     LogisticRegression      0.376000  0.068855  0.000000
# ...

# %%
Table(BC, 'BC_VisualisationPreparation.csv', 2 )
# Out:
#                                             Accuracy            Matthews  \
#                                                 mean       std      mean
# EmbMethod InputSize Method
# bertcode  10        Decision Tree           0.630357  0.229825  0.301891
#                     GaussianNB              0.559373  0.254666  0.292170
#                     LinearSVC               0.596609  0.287449  0.260648
#                     LogisticRegression      0.527183  0.276668  0.208374
#                     MLPClassifier           0.694572  0.180949  0.182513
#                     RandomForestClassifier  0.651188  0.215337  0.230882
#           100       Decision Tree           0.593983  0.146478  0.284752
#                     GaussianNB              0.670926  0.154908  0.443545
#                     LinearSVC               0.507821  0.325638  0.016018
#                     LogisticRegression      0.474168  0.087730  0.000000
# ...

# %% [markdown]
# ## Test Regime 3
#
# Train and test do not have nodes sharing the same direct arc

# %%
Table(BC, 'BC_OutputTemporary.csv', 3 )
# Out:
#                                             Accuracy            Matthews  \
#                                                 mean       std      mean
# EmbMethod InputSize Method
# bertcode  10        Decision Tree           0.598523  0.229993  0.151653
#                     GaussianNB              0.668127  0.246055  0.288115
#                     LinearSVC               0.534226  0.360969  0.017025
#                     LogisticRegression      0.548043  0.241415  0.006670
#                     MLPClassifier           0.539413  0.266130  0.062996
#                     RandomForestClassifier  0.679987  0.197326  0.309993
#           100       Decision Tree           0.643638  0.140073  0.345317
#                     GaussianNB              0.585287  0.108802  0.193939
#                     LinearSVC               0.553995  0.311350  0.121423
#                     LogisticRegression      0.497655  0.039154  0.000000
# ...

# %%
Table(BC, 'BC_VisualisationPreparation.csv', 3 )
# Out:
#                                             Accuracy            Matthews  \
#                                                 mean       std      mean
# EmbMethod InputSize Method
# bertcode  10        Decision Tree           0.564900  0.171080 -0.103612
#                     GaussianNB              0.524171  0.171608  0.001385
#                     LinearSVC               0.517413  0.181368  0.014886
#                     LogisticRegression      0.550720  0.165002 -0.039084
#                     MLPClassifier           0.448322  0.181513 -0.000551
#                     RandomForestClassifier  0.462137  0.162956 -0.005686
#           100       Decision Tree           0.509046  0.062078 -0.021076
#                     GaussianNB              0.470157  0.045299  0.000000
#                     LinearSVC               0.509573  0.118108  0.030653
#                     LogisticRegression      0.487025  0.053428  0.000000
# ...
