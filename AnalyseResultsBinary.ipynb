# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
BC = pd.read_csv("ClassificationExperiments.csv",names=["Dataset", "Notebooks", "InputSize", "TestRegime", "Method", "Accuracy", "Matthews", "F1:A", "F1:B" ])
# Preview the first 5 lines of the loaded data 
# data.head()
BC.size
# Out:
# 9720

# %%
BC['Method'].unique()
# Out:
# array(['Decision Tree', 'GaussianNB', 'LogisticRegression', 'LinearSVC',
#        'MLPClassifier', 'RandomForestClassifier'], dtype=object)

# %%
#

# %%
# Group data by Dataset/InputSize/TestRegime/Method and compute AVG & STD on each Measures
# avg = data[(data['Dataset']=='BC_VisualisationPreparation.csv') & (data['InputSize']==10) & (data['TestRegime']==1) & (data['Method']=='Decision Tree')].mean()
# std = data[(data['Dataset']=='BC_VisualisationPreparation.csv') & (data['InputSize']==10) & (data['TestRegime']==1) & (data['Method']=='Decision Tree')].std()
# avg, std
# # https://stackoverflow.com/questions/36106490/how-to-get-unique-values-from-multiple-columns-in-a-pandas-groupby

# %%
def Table(dataframe, dataset, test_regime):
    # VP, TestRegime 1
    df = dataframe[dataframe['Dataset'] == dataset].drop(columns=['Notebooks','Dataset'])
    TR = df.loc[df['TestRegime']==test_regime].drop(columns=['TestRegime'])
    return TR.groupby(['InputSize','Method']).agg(['mean','std'])

# %%
# Train and test entities randomly split
# Train and test do not share notebooks
# Train and test do not have nodes sharing the same direct arc
Table(BC, 'BC_OutputTemporary.csv', 1 )
# Out:
#                                   Accuracy            Matthews            \
#                                       mean       std      mean       std
# InputSize Method
# 10        Decision Tree           0.504330  0.186135  0.046649  0.171990
#           GaussianNB              0.647825  0.174613  0.344814  0.182303
#           LinearSVC               0.677688  0.112878  0.157754  0.167372
#           LogisticRegression      0.674615  0.119452  0.144885  0.161636
#           MLPClassifier           0.705444  0.127279  0.271094  0.227537
#           RandomForestClassifier  0.533163  0.185722  0.138333  0.181759
# 100       Decision Tree           0.545482  0.198018  0.105546  0.276489
#           GaussianNB              0.705721  0.021109  0.299981  0.038152
#           LinearSVC               0.707156  0.090138  0.319421  0.135025
#           LogisticRegression      0.737833  0.046007  0.337361  0.140034
#           MLPClassifier           0.640608  0.176371  0.258286  0.218243
#           RandomForestClassifier  0.585454  0.179537  0.204176  0.229820
# 200       Decision Tree           0.489444  0.147643  0.034121  0.220718
#           GaussianNB              0.687658  0.013662  0.282323  0.031921
#           LinearSVC               0.697546  0.156752  0.374235  0.275190
#           LogisticRegression      0.772399  0.070333  0.483118  0.163978
#           MLPClassifier           0.658013  0.201774  0.308099  0.330308
#           RandomForestClassifier  0.610493  0.175186  0.233217  0.273429
#
#                                       F1:A                F1:B
#                                       mean       std      mean       std
# InputSize Method
# 10        Decision Tree           0.369545  0.211671  0.446074  0.329354
#           GaussianNB              0.594261  0.149613  0.648641  0.247942
#           LinearSVC               0.136058  0.144767  0.795123  0.088793
#           LogisticRegression      0.112459  0.139785  0.794186  0.092022
#           MLPClassifier           0.286240  0.267238  0.805718  0.093795
#           RandomForestClassifier  0.470786  0.158757  0.393170  0.347765
# 100       Decision Tree           0.463685  0.102054  0.562166  0.272775
#           GaussianNB              0.506082  0.028698  0.789943  0.019448
#           LinearSVC               0.493127  0.146302  0.773138  0.139057
#           LogisticRegression      0.457849  0.160872  0.824444  0.030285
#           MLPClassifier           0.484030  0.145732  0.670187  0.257625
#           RandomForestClassifier  0.504114  0.102219  0.602386  0.242347
# 200       Decision Tree           0.469908  0.079505  0.484272  0.212073
#           GaussianNB              0.499276  0.024793  0.772827  0.011881
#           LinearSVC               0.579537  0.143534  0.742020  0.183306
#           LogisticRegression      0.619433  0.131782  0.835597  0.051396
#           MLPClassifier           0.553866  0.170998  0.680443  0.261725
#           RandomForestClassifier  0.546484  0.098012  0.624562  0.242989

# %%
Table(BC, 'BC_VisualisationPreparation.csv', 1 )
# Out:
#                                   Accuracy            Matthews            \
#                                       mean       std      mean       std
# InputSize Method
# 10        Decision Tree           0.565582  0.098366  0.172315  0.190485
#           GaussianNB              0.616725  0.103210  0.193326  0.218937
#           LinearSVC               0.543147  0.085770  0.085569  0.161991
#           LogisticRegression      0.617624  0.102811  0.239441  0.218399
#           MLPClassifier           0.562533  0.101334  0.142815  0.225795
#           RandomForestClassifier  0.593201  0.092308  0.150424  0.173258
# 100       Decision Tree           0.544375  0.065260  0.071651  0.132906
#           GaussianNB              0.576481  0.053096  0.158896  0.104815
#           LinearSVC               0.635524  0.095610  0.271946  0.196049
#           LogisticRegression      0.646841  0.096184  0.296170  0.201715
#           MLPClassifier           0.673451  0.106328  0.344632  0.220397
#           RandomForestClassifier  0.630985  0.078067  0.247851  0.165150
# 200       Decision Tree           0.554655  0.056760  0.118169  0.127948
#           GaussianNB              0.549773  0.027533  0.112414  0.055196
#           LinearSVC               0.741295  0.078655  0.492540  0.159037
#           LogisticRegression      0.747235  0.085600  0.502588  0.175953
#           MLPClassifier           0.717598  0.085923  0.451843  0.174477
#           RandomForestClassifier  0.683493  0.052210  0.375641  0.105500
#
#                                       F1:A                F1:B
#                                       mean       std      mean       std
# InputSize Method
# 10        Decision Tree           0.455894  0.290985  0.527599  0.199806
#           GaussianNB              0.497004  0.296026  0.584626  0.226654
#           LinearSVC               0.432476  0.285114  0.505652  0.170156
#           LogisticRegression      0.492931  0.287936  0.603815  0.175830
#           MLPClassifier           0.522522  0.276942  0.415228  0.241945
#           RandomForestClassifier  0.545663  0.252546  0.431852  0.290732
# 100       Decision Tree           0.471554  0.116338  0.587660  0.069222
#           GaussianNB              0.574265  0.054125  0.576392  0.059019
#           LinearSVC               0.546329  0.127794  0.690183  0.090396
#           LogisticRegression      0.547799  0.131521  0.705629  0.087461
#           MLPClassifier           0.608655  0.140374  0.716700  0.089690
#           RandomForestClassifier  0.510118  0.164342  0.695163  0.055368
# 200       Decision Tree           0.545657  0.094272  0.550197  0.066324
#           GaussianNB              0.578170  0.022007  0.516562  0.038718
#           LinearSVC               0.724334  0.111520  0.747992  0.075285
#           LogisticRegression      0.719183  0.123610  0.762928  0.072247
#           MLPClassifier           0.710519  0.120155  0.711465  0.088664
#           RandomForestClassifier  0.659980  0.084034  0.696020  0.052485

# %%
data[(data['Dataset']=='BC_VisualisationPreparation.csv') & (data['InputSize']==10) & (data['TestRegime']==1) & (data['Method']=='Decision Tree')]
# Out:
#                             Dataset  \
# 0   BC_VisualisationPreparation.csv
# 6   BC_VisualisationPreparation.csv
# 12  BC_VisualisationPreparation.csv
# 18  BC_VisualisationPreparation.csv
# 24  BC_VisualisationPreparation.csv
# 30  BC_VisualisationPreparation.csv
# 36  BC_VisualisationPreparation.csv
# 42  BC_VisualisationPreparation.csv
# 48  BC_VisualisationPreparation.csv
# 54  BC_VisualisationPreparation.csv
#
#                                             Notebooks  InputSize  TestRegime  \
# 0   pre-processing-train-and-test-images.digraph,k...         10           1
# 6   cloud-classifier-for-post-processing.digraph,s...         10           1
# 12  mask-rcnn-and-coco-transfer-learning-lb-0-155....         10           1
# 18  end-to-end-project-with-python.digraph,aligned...         10           1
# 24  unrolling-of-helices-outliers-removal.digraph,...         10           1
# 30  getting-started-with-cnn-and-vgg16.digraph,int...         10           1
# 36  dog-breed-pretrained-keras-models-lb-0-3.digra...         10           1
# 42  imdb-review-deep-model-94-89-accuracy.digraph,...         10           1
# 48  a-method-to-valid-offline-lb-9506.digraph,lite...         10           1
# 54  bond-calculation-lb-0-82.digraph,eda-script-67...         10           1
#
#            Method  Accuracy        F1  Matthews
# 0   Decision Tree  0.423077  0.571429 -0.255994
# 6   Decision Tree  0.543478  0.222222  0.033806
# 12  Decision Tree  0.352113  0.258065 -0.316393
# 18  Decision Tree  0.607143  0.702703  0.138749
# 24  Decision Tree  0.520000  0.555556  0.033816
# 30  Decision Tree  0.612903  0.760000  0.000000
# 36  Decision Tree  0.600000  0.750000  0.000000
# 42  Decision Tree  0.470588  0.550000 -0.003949
# 48  Decision Tree  0.484848  0.260870  0.046291
# 54  Decision Tree  0.441860  0.478261 -0.114045
